# %%
# %pip install -q diffusers;
# %pip install -q accelerate;

# %%
from diffusers import DDIMPipeline
import accelerate
import torch
import matplotlib.pyplot as plt

seed = 2678

torch.manual_seed(seed)
generator = torch.Generator()

model_id = "google/ddpm-cifar10-32"

# load model and scheduler
pipeline = DDIMPipeline.from_pretrained(model_id)

# run pipeline in inference (sample random noise and denoise)
generated_images = pipeline(1000, generator = generator).images
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
generated_images[1]
# Out:
# <PIL.Image.Image image mode=RGB size=32x32>

# %%
for i, pic in enumerate(generated_images):
  pic.save(f"cifar_generated/cifar_generated_{i}.png")

# %%
# !zip -r /content/cifar_generated.zip /content/cifar_generated
# Out:
#   adding: content/cifar_generated/ (stored 0%)
#   adding: content/cifar_generated/cifar_generated_542.png (stored 0%)
#   adding: content/cifar_generated/cifar_generated_723.png (stored 0%)
#   adding: content/cifar_generated/cifar_generated_784.png (stored 0%)
#   adding: content/cifar_generated/cifar_generated_837.png (stored 0%)
#   adding: content/cifar_generated/cifar_generated_374.png (stored 0%)
#   adding: content/cifar_generated/cifar_generated_790.png (stored 0%)
#   adding: content/cifar_generated/cifar_generated_247.png (stored 0%)
#   adding: content/cifar_generated/cifar_generated_34.png (stored 0%)
#   adding: content/cifar_generated/cifar_generated_454.png (stored 0%)
#   adding: content/cifar_generated/cifar_generated_732.png (stored 0%)
#   adding: content/cifar_generated/cifar_generated_877.png (stored 0%)
#   adding: content/cifar_generated/cifar_generated_227.png (stored 0%)
#   adding: content/cifar_generated/cifar_generated_89.png (stored 0%)
# ...
